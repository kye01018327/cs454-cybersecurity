# %%
from aes import *
from utils import *

# %%
# Testing for Key Expansion
plaintext = 0x0123456789abcdeffedcba9876543210
key = 0x0f1571c947d9e8590cb7add6af7f6798

# print(hex(plaintext ^ key))
demo_avalanche_effect(plaintext, key)
# Out:
# 0xe3634aece7225b6f26b174ed92b5588

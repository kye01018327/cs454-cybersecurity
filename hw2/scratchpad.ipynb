# %%
from AES import *
from utils import *

# %%
# Testing for Key Expansion
plaintext = convert_int_to_matrix(0x0123456789abcdeffedcba9876543210)
key = convert_int_to_matrix(0x0f1571c947d9e8590cb7add6af7f6798)

aes_encrypt(plaintext, key)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 5
#       2 plaintext = 0x0123456789abcdeffedcba9876543210
#       3 key = convert_int_to_matrix(0x0f1571c947d9e8590cb7add6af7f6798)
# ----> 5 aes_encrypt(plaintext, key)
#
# File ~/projects/cs454-cybersecurity/hw2/AES.py:157, in aes_encrypt(plaintext, key)
#     155 state = plaintext
#     156 keys = key_expansion(key)
# --> 157 state = add_round_key(state, keys[0])
#     158 # For 9 rounds
#     159 for round_key in keys[1:10]:
#
# File ~/projects/cs454-cybersecurity/hw2/AES.py:95, in add_round_key(input_matrix, key_matrix)
#      91 def add_round_key(input_matrix: list[list[int]], key_matrix: list[list[int]]) -> list[list[int]]:
#      92     # Accept a 4 by 4 state matrix as input
#      93     # Perform a bitwise XOR between the state and the round key.
#      94     transformed_matrix = []
# ---> 95     for state_row, key_row in zip(input_matrix, key_matrix):
#      96         transformed_row = []
#      97         for state_byte, key_byte in zip(state_row, key_row):
#
# TypeError: 'int' object is not iterable

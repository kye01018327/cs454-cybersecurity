# %%
from AES import *
from utils import *

# %%
block = convert_int_to_block(plaintext)
integer = convert_block_to_int(block)
print(hex(integer))
# Out:
# 0x123456789abcdef0123456789abcdef

# %%
printb(block)
printb(shift_rows(block))
# Out:
# [[1, 35, 69, 103], [137, 171, 205, 239], [1, 35, 69, 103], [137, 171, 205, 239]]
# [1, 35, 69, 103] [171, 205, 239, 137] [69, 103, 1, 35] [239, 137, 171, 205]

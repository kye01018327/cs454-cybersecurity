# %%
from AES import *
from utils import *

# %%
plaintext_matrix = convert_int_to_matrix(0xd4e0b81e27bfb44111985d52aef1e530)
key_matrix = convert_int_to_matrix(key)

# %%
printb(plaintext_matrix, '')
printb(shift_rows(plaintext_matrix), '')
print(hex(convert_matrix_to_int(shift_rows(plaintext_matrix))))
# Out:
# [0xd4 0x27 0x11 0xae ]
# [0xe0 0xbf 0x98 0xf1 ]
# [0xb8 0xb4 0x5d 0xe5 ]
# [0x1e 0x41 0x52 0x30 ]
#
# [0xd4 0x27 0x11 0xae ]
# [0xbf 0x98 0xf1 0xe0 ]
# [0x5d 0xe5 0xb8 0xb4 ]
# [0x30 0x1e 0x41 0x52 ]

# %%
print(hex(aes_encrypt(plaintext, key)))
# Out:
# 0xc2295810b26111eaa42e243c09412506

# %%
from AES import *
from utils import *

# %%
state_block = convert_int_to_matrix(plaintext)
key_block = convert_int_to_matrix(key)

# %%
printb(state_block)
printb(key_block)
printb(add_round_key(state_block, key_block))
# Out:
# [0x1 0x23 0x45 0x67 ]
# [0x89 0xab 0xcd 0xef ]
# [0x1 0x23 0x45 0x67 ]
# [0x89 0xab 0xcd 0xef ]
#
# [0x1 0x23 0x45 0x67 ]
# [0x89 0xab 0xcd 0xef ]
# [0x1 0x23 0x45 0x67 ]
# [0x89 0xab 0xcd 0xef ]
#
# [0x0 0x0 0x0 0x0 ]
# [0x0 0x0 0x0 0x0 ]
# [0x0 0x0 0x0 0x0 ]
# [0x0 0x0 0x0 0x0 ]

# %%
print(state_block[0])
print(sub_word(state_block[0]))
# Out:
# [1, 35, 69, 103]
# [124, 38, 110, 133]

# %%
printb(state_block)
printb(mix_columns(state_block))
# Out:
# [0xa 0x28 0x4e 0x6c ]
# [0x82 0xa0 0xc6 0xe4 ]
# [0xa 0x28 0x4e 0x6c ]
# [0x82 0xa0 0xc6 0xe4 ]
#
# [0x1 0x23 0x45 0x67 ]
# [0x89 0xab 0xcd 0xef ]
# [0x1 0x23 0x45 0x67 ]
# [0x89 0xab 0xcd 0xef ]

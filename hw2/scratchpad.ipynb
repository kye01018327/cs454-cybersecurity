# %%
from AES import *
from util import *
from test_data import *

# %%
block = convert_int_to_block(plaintext)
integer = convert_block_to_int(block)
print(hex(integer))
# Out:
# 0x123456789abcdef0123456789abcdef

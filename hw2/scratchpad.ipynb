# %%
from AES import *
from utils import *

# %%
plaintext_matrix = convert_int_to_matrix(plaintext)
key_matrix = convert_int_to_matrix(key)

# %%
shift_rows(plaintext_matrix)
# Out:
# SUB BYTES
# INPUT
# [0x0 0x44 0x88 0xcc ]
# [0x11 0x55 0x99 0xdd ]
# [0x22 0x66 0xaa 0xee ]
# [0x33 0x77 0xbb 0xff ]
#
# OUTPUT
# [0x63 0x1b 0xc4 0x4b ]
# [0x82 0xfc 0xee 0xc1 ]
# [0x93 0x33 0xac 0x28 ]
# [0xc3 0xf5 0xea 0x16 ]
# [[99, 27, 196, 75],
#  [130, 252, 238, 193],
#  [147, 51, 172, 40],
#  [195, 245, 234, 22]]

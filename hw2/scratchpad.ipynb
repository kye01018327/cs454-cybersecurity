# %%
from aes import *
from utils import *

# %%
# AES Encrypt / Decrypt
textbook_plaintext = 0x0123456789abcdeffedcba9876543210
textbook_key = 0x0f1571c947d9e8590cb7add6af7f6798
textbook_ciphertext = 0xff0b844a0853bf7c6934ab4364148fb9

ciphertext = aes_encrypt(textbook_plaintext, textbook_key)
plaintext = aes_decrypt(ciphertext, textbook_key)

print(f'Textbook Plaintext   : {hex(textbook_plaintext)}')
print(f'Textbook Key         : {hex(textbook_key)}')
print()

print(f'Generated Ciphertext : {hex(ciphertext)}')
print(f'Expected Ciphertext  : {hex(textbook_ciphertext)}')
print()

print(f'Deciphered Ciphertext: {hex(plaintext)}')
print(f'Expected Plaintext   : {hex(textbook_plaintext)}')
# Out:
# Textbook Plaintext   : 0x123456789abcdeffedcba9876543210
# Textbook Key         : 0xf1571c947d9e8590cb7add6af7f6798
#
# Generated Ciphertext : 0xff0b844a0853bf7c6934ab4364148fb9
# Expected Ciphertext  : 0xff0b844a0853bf7c6934ab4364148fb9
#
# Deciphered Ciphertext: 0x123456789abcdeffedcba9876543210
# Expected Plaintext   : 0x123456789abcdeffedcba9876543210

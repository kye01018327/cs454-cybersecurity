# %%
from AES import *
from utils import *

# %%
plaintext_matrix = convert_int_to_matrix(plaintext)
key_matrix = convert_int_to_matrix(key)

# %%
print("plaintext")
printb(plaintext_matrix)
print("key")
printb(key_matrix)
print("result")
result = mix_columns(plaintext_matrix)
printb(result)
# Out:
# plaintext
# [0x0 0x44 0x88 0xcc ]
# [0x11 0x55 0x99 0xdd ]
# [0x22 0x66 0xaa 0xee ]
# [0x33 0x77 0xbb 0xff ]
#
# key
# [0x0 0x4 0x8 0xc ]
# [0x1 0x5 0x9 0xd ]
# [0x2 0x6 0xa 0xe ]
# [0x3 0x7 0xb 0xf ]
#
# result
# [0x22 0x66 0xaa 0xee ]
# [0x77 0x33 0xff 0xbb ]
# [0x0 0x44 0x88 0xcc ]
# [0x55 0x11 0xdd 0x99 ]

# %%
print("key")
printb(key_matrix)
print("result")
print(key_expansion(key_matrix))
# Out:
# key
# [0x0 0x4 0x8 0xc ]
# [0x1 0x5 0x9 0xd ]
# [0x2 0x6 0xa 0xe ]
# [0x3 0x7 0xb 0xf ]
#
# result
# [[0, 4, 8, 12], [1, 5, 9, 13], [2, 6, 10, 14], [3, 7, 11, 15], [196, 47, 126, 119], [197, 42, 119, 122], [199, 44, 125, 116], [196, 43, 118, 123], [53, 43, 223, 144], [240, 1, 168, 234], [55, 45, 213, 158], [243, 6, 163, 229], [94, 37, 48, 156], [174, 36, 152, 118], [153, 9, 77, 232], [106, 15, 238, 13], [32, 133, 231, 106], [142, 161, 127, 28], [23, 168, 50, 244], [125, 167, 220, 249], [110, 107, 145, 142], [224, 202, 238, 146], [247, 98, 220, 102], [138, 197, 0, 159], [35, 8, 59, 36], [195, 194, 213, 182], [52, 160, 9, 208], [190, 101, 9, 79], [195, 9, 91, 54], [0, 203, 142, 128], [52, 107, 135, 80], [138, 14, 142, 31], [232, 27, 143, 156], [232, 208, 1, 28], [220, 187, 134, 76], [86, 181, 8, 83], [114, 43, 43, 49], [154, 251, 42, 45], [70, 64, 172, 97], [16, 245, 164, 50], [146, 241, 56, 251], [8, 10, 18, 214], [78, 74, 190, 183], [94, 191, 26, 133]]

# %%
print("plaintext")
print(hex(plaintext))
print("key")
print(hex(key))
print("encrypt")
print(hex(aes_encrypt(plaintext, key)))
# Out:
# plaintext
# 88962710306127702866241727433142015
# key
# 5233100606242806050955395731361295
# encrypt
# 45923284038666488760627577140922225802

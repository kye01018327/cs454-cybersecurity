# %%
from AES import *
from utils import *

# %%
plaintext_matrix = convert_int_to_matrix(plaintext)
key_matrix = convert_int_to_matrix(key)

# %%
key_expansion(key_matrix)
# Out:
# CIPHER KEY
# [0x2b 0x7e 0x15 0x16 ]
# [0x28 0xae 0xd2 0xa6 ]
# [0xab 0xf7 0x15 0x88 ]
# [0x9 0xcf 0x4f 0x3c ]
#
# OUTPUT
# ['0x2b', '0x7e', '0x15', '0x16']
# ['0x28', '0xae', '0xd2', '0xa6']
# ['0xab', '0xf7', '0x15', '0x88']
# ['0x9', '0xcf', '0x4f', '0x3c']
# ['0xa0', '0xfa', '0xfe', '0x17']
# ['0x88', '0x54', '0x2c', '0xb1']
# ['0x23', '0xa3', '0x39', '0x39']
# ['0x2a', '0x6c', '0x76', '0x5']
# ['0xf2', '0xc2', '0x95', '0xf2']
# ['0x7a', '0x96', '0xb9', '0x43']
# ['0x59', '0x35', '0x80', '0x7a']
# ['0x73', '0x59', '0xf6', '0x7f']
# ['0x3d', '0x80', '0x47', '0x7d']
# ['0x47', '0x16', '0xfe', '0x3e']
# ['0x1e', '0x23', '0x7e', '0x44']
# ['0x6d', '0x7a', '0x88', '0x3b']
# ['0xef', '0x44', '0xa5', '0x41']
# ['0xa8', '0x52', '0x5b', '0x7f']
# ['0xb6', '0x71', '0x25', '0x3b']
# ['0xdb', '0xb', '0xad', '0x0']
# ['0xd4', '0xd1', '0xc6', '0xf8']
# ['0x7c', '0x83', '0x9d', '0x87']
# ['0xca', '0xf2', '0xb8', '0xbc']
# ['0x11', '0xf9', '0x15', '0xbc']
# ['0x6d', '0x88', '0xa3', '0x7a']
# ['0x11', '0xb', '0x3e', '0xfd']
# ['0xdb', '0xf9', '0x86', '0x41']
# ['0xca', '0x0', '0x93', '0xfd']
# ['0x4e', '0x54', '0xf7', '0xe']
# ['0x5f', '0x5f', '0xc9', '0xf3']
# ['0x84', '0xa6', '0x4f', '0xb2']
# ['0x4e', '0xa6', '0xdc', '0x4f']
# ['0xea', '0xd2', '0x73', '0x21']
# ['0xb5', '0x8d', '0xba', '0xd2']
# ['0x31', '0x2b', '0xf5', '0x60']
# ['0x7f', '0x8d', '0x29', '0x2f']
# ['0xac', '0x77', '0x66', '0xf3']
# ['0x19', '0xfa', '0xdc', '0x21']
# ['0x28', '0xd1', '0x29', '0x41']
# ['0x57', '0x5c', '0x0', '0x6e']
# ['0xd0', '0x14', '0xf9', '0xa8']
# ['0xc9', '0xee', '0x25', '0x89']
# ['0xe1', '0x3f', '0xc', '0xc8']
# ['0xb6', '0x63', '0xc', '0xa6']
# [[43, 126, 21, 22],
#  [40, 174, 210, 166],
#  [171, 247, 21, 136],
#  [9, 207, 79, 60],
#  [160, 250, 254, 23],
#  [136, 84, 44, 177],
#  [35, 163, 57, 57],
#  [42, 108, 118, 5],
#  [242, 194, 149, 242],
#  [122, 150, 185, 67],
#  [89, 53, 128, 122],
#  [115, 89, 246, 127],
#  [61, 128, 71, 125],
#  [71, 22, 254, 62],
#  [30, 35, 126, 68],
#  [109, 122, 136, 59],
#  [239, 68, 165, 65],
#  [168, 82, 91, 127],
#  [182, 113, 37, 59],
#  [219, 11, 173, 0],
#  [212, 209, 198, 248],
#  [124, 131, 157, 135],
#  [202, 242, 184, 188],
#  [17, 249, 21, 188],
#  [109, 136, 163, 122],
#  [17, 11, 62, 253],
#  [219, 249, 134, 65],
#  [202, 0, 147, 253],
#  [78, 84, 247, 14],
#  [95, 95, 201, 243],
#  [132, 166, 79, 178],
#  [78, 166, 220, 79],
#  [234, 210, 115, 33],
#  [181, 141, 186, 210],
#  [49, 43, 245, 96],
#  [127, 141, 41, 47],
#  [172, 119, 102, 243],
#  [25, 250, 220, 33],
#  [40, 209, 41, 65],
#  [87, 92, 0, 110],
#  [208, 20, 249, 168],
#  [201, 238, 37, 137],
#  [225, 63, 12, 200],
#  [182, 99, 12, 166]]

# %%
print(hex(aes_encrypt(plaintext, key)))
# Out:
# CIPHER KEY
# [0x2b 0x7e 0x15 0x16 ]
# [0x28 0xae 0xd2 0xa6 ]
# [0xab 0xf7 0x15 0x88 ]
# [0x9 0xcf 0x4f 0x3c ]
#
# OUTPUT
# ['0x2b', '0x7e', '0x15', '0x16']
# ['0x28', '0xae', '0xd2', '0xa6']
# ['0xab', '0xf7', '0x15', '0x88']
# ['0x9', '0xcf', '0x4f', '0x3c']
# ['0xa0', '0xfa', '0xfe', '0x17']
# ['0x88', '0x54', '0x2c', '0xb1']
# ['0x23', '0xa3', '0x39', '0x39']
# ['0x2a', '0x6c', '0x76', '0x5']
# ['0xf2', '0xc2', '0x95', '0xf2']
# ['0x7a', '0x96', '0xb9', '0x43']
# ['0x59', '0x35', '0x80', '0x7a']
# ['0x73', '0x59', '0xf6', '0x7f']
# ['0x3d', '0x80', '0x47', '0x7d']
# ['0x47', '0x16', '0xfe', '0x3e']
# ['0x1e', '0x23', '0x7e', '0x44']
# ['0x6d', '0x7a', '0x88', '0x3b']
# ['0xef', '0x44', '0xa5', '0x41']
# ['0xa8', '0x52', '0x5b', '0x7f']
# ['0xb6', '0x71', '0x25', '0x3b']
# ['0xdb', '0xb', '0xad', '0x0']
# ['0xd4', '0xd1', '0xc6', '0xf8']
# ['0x7c', '0x83', '0x9d', '0x87']
# ['0xca', '0xf2', '0xb8', '0xbc']
# ['0x11', '0xf9', '0x15', '0xbc']
# ['0x6d', '0x88', '0xa3', '0x7a']
# ['0x11', '0xb', '0x3e', '0xfd']
# ['0xdb', '0xf9', '0x86', '0x41']
# ['0xca', '0x0', '0x93', '0xfd']
# ['0x4e', '0x54', '0xf7', '0xe']
# ['0x5f', '0x5f', '0xc9', '0xf3']
# ['0x84', '0xa6', '0x4f', '0xb2']
# ['0x4e', '0xa6', '0xdc', '0x4f']
# ['0xea', '0xd2', '0x73', '0x21']
# ['0xb5', '0x8d', '0xba', '0xd2']
# ['0x31', '0x2b', '0xf5', '0x60']
# ['0x7f', '0x8d', '0x29', '0x2f']
# ['0xac', '0x77', '0x66', '0xf3']
# ['0x19', '0xfa', '0xdc', '0x21']
# ['0x28', '0xd1', '0x29', '0x41']
# ['0x57', '0x5c', '0x0', '0x6e']
# ['0xd0', '0x14', '0xf9', '0xa8']
# ['0xc9', '0xee', '0x25', '0x89']
# ['0xe1', '0x3f', '0xc', '0xc8']
# ['0xb6', '0x63', '0xc', '0xa6']
# INPUT
# [0x32 0x88 0x31 0xe0 ]
# [0x43 0x5a 0x31 0x37 ]
# [0xf6 0x30 0x98 0x7 ]
# [0xa8 0x8d 0xa2 0x34 ]
#
# CIPHER KEY
# [0x2b 0x7e 0x15 0x16 ]
# [0x28 0xae 0xd2 0xa6 ]
# [0xab 0xf7 0x15 0x88 ]
# [0x9 0xcf 0x4f 0x3c ]
#
# OUTPUT
# [0x19 0xf6 0x24 0xf6 ]
# [0x6b 0xf4 0xe3 0x91 ]
# [0x5d 0xc7 0x8d 0x8f ]
# [0xa1 0x42 0xed 0x8 ]
#
# SUB BYTES
# INPUT
# [0x19 0xf6 0x24 0xf6 ]
# [0x6b 0xf4 0xe3 0x91 ]
# [0x5d 0xc7 0x8d 0x8f ]
# [0xa1 0x42 0xed 0x8 ]
#
# OUTPUT
# [0xd4 0x42 0x36 0x42 ]
# [0x7f 0xbf 0x11 0x81 ]
# [0x4c 0xc6 0x5d 0x73 ]
# [0x32 0x2c 0x55 0x30 ]
#
# INPUT
# [0xd4 0x42 0x36 0x42 ]
# [0x7f 0xbf 0x11 0x81 ]
# [0x4c 0xc6 0x5d 0x73 ]
# [0x32 0x2c 0x55 0x30 ]
#
# OUTPUT
# [0xd4 0x42 0x36 0x42 ]
# [0xbf 0x11 0x81 0x7f ]
# [0x5d 0x73 0x4c 0xc6 ]
# [0x30 0x32 0x2c 0x55 ]
#
# INPUT
# [0xd4 0x42 0x36 0x42 ]
# [0xbf 0x11 0x81 0x7f ]
# [0x5d 0x73 0x4c 0xc6 ]
# [0x30 0x32 0x2c 0x55 ]
#
# OUTPUT
# [0x4 0x66 0x81 0xe5 ]
# [0xf6 0xc7 0xe3 0xc0 ]
# [0x94 0xd7 0x5b 0xcf ]
# [0x96 0xb8 0x55 0xd5 ]
#
# INPUT
# [0x4 0x66 0x81 0xe5 ]
# [0xf6 0xc7 0xe3 0xc0 ]
# [0x94 0xd7 0x5b 0xcf ]
# [0x96 0xb8 0x55 0xd5 ]
#
# CIPHER KEY
# [0xa0 0xfa 0xfe 0x17 ]
# [0x88 0x54 0x2c 0xb1 ]
# [0x23 0xa3 0x39 0x39 ]
# [0x2a 0x6c 0x76 0x5 ]
#
# OUTPUT
# [0xa4 0x9c 0x7f 0xf2 ]
# [0x7e 0x93 0xcf 0x71 ]
# [0xb7 0x74 0x62 0xf6 ]
# [0xbc 0xd4 0x23 0xd0 ]
#
# SUB BYTES
# INPUT
# [0xa4 0x9c 0x7f 0xf2 ]
# [0x7e 0x93 0xcf 0x71 ]
# [0xb7 0x74 0x62 0xf6 ]
# [0xbc 0xd4 0x23 0xd0 ]
#
# OUTPUT
# [0x49 0xde 0xd2 0x89 ]
# [0xf3 0xdc 0x8a 0xa3 ]
# [0xa9 0x92 0xaa 0x42 ]
# [0x65 0x48 0x26 0x70 ]
#
# INPUT
# [0x49 0xde 0xd2 0x89 ]
# [0xf3 0xdc 0x8a 0xa3 ]
# [0xa9 0x92 0xaa 0x42 ]
# [0x65 0x48 0x26 0x70 ]
#
# OUTPUT
# [0x49 0xde 0xd2 0x89 ]
# [0xdc 0x8a 0xa3 0xf3 ]
# [0xaa 0x42 0xa9 0x92 ]
# [0x70 0x65 0x48 0x26 ]
#
# INPUT
# [0x49 0xde 0xd2 0x89 ]
# [0xdc 0x8a 0xa3 0xf3 ]
# [0xaa 0x42 0xa9 0x92 ]
# [0x70 0x65 0x48 0x26 ]
#
# OUTPUT
# [0x37 0x7f 0x4a 0x4d ]
# [0x5 0x72 0x7f 0x7b ]
# [0xa0 0x27 0xe0 0xf7 ]
# [0xb3 0xff 0x2f 0xad ]
#
# INPUT
# [0x37 0x7f 0x4a 0x4d ]
# [0x5 0x72 0x7f 0x7b ]
# [0xa0 0x27 0xe0 0xf7 ]
# [0xb3 0xff 0x2f 0xad ]
#
# CIPHER KEY
# [0xf2 0xc2 0x95 0xf2 ]
# [0x7a 0x96 0xb9 0x43 ]
# [0x59 0x35 0x80 0x7a ]
# [0x73 0x59 0xf6 0x7f ]
#
# OUTPUT
# [0xc5 0xbd 0xdf 0xbf ]
# [0x7f 0xe4 0xc6 0x38 ]
# [0xf9 0x12 0x60 0x8d ]
# [0xc0 0xa6 0xd9 0xd2 ]
#
# SUB BYTES
# INPUT
# [0xc5 0xbd 0xdf 0xbf ]
# [0x7f 0xe4 0xc6 0x38 ]
# [0xf9 0x12 0x60 0x8d ]
# [0xc0 0xa6 0xd9 0xd2 ]
#
# OUTPUT
# [0xa6 0x7a 0x9e 0x8 ]
# [0xd2 0x69 0xb4 0x7 ]
# [0x99 0xc9 0xd0 0x5d ]
# [0xba 0x24 0x35 0xb5 ]
#
# INPUT
# [0xa6 0x7a 0x9e 0x8 ]
# [0xd2 0x69 0xb4 0x7 ]
# [0x99 0xc9 0xd0 0x5d ]
# [0xba 0x24 0x35 0xb5 ]
#
# OUTPUT
# [0xa6 0x7a 0x9e 0x8 ]
# [0x69 0xb4 0x7 0xd2 ]
# [0xd0 0x5d 0x99 0xc9 ]
# [0xb5 0xba 0x24 0x35 ]
#
# INPUT
# [0xa6 0x7a 0x9e 0x8 ]
# [0x69 0xb4 0x7 0xd2 ]
# [0xd0 0x5d 0x99 0xc9 ]
# [0xb5 0xba 0x24 0x35 ]
#
# OUTPUT
# [0x89 0xaa 0xb0 0x39 ]
# [0xd4 0x54 0xa1 0x8 ]
# [0x93 0x4 0xdc 0x6f ]
# [0x81 0xc2 0xc 0x69 ]
#
# INPUT
# [0x89 0xaa 0xb0 0x39 ]
# [0xd4 0x54 0xa1 0x8 ]
# [0x93 0x4 0xdc 0x6f ]
# [0x81 0xc2 0xc 0x69 ]
#
# CIPHER KEY
# [0x3d 0x80 0x47 0x7d ]
# [0x47 0x16 0xfe 0x3e ]
# [0x1e 0x23 0x7e 0x44 ]
# [0x6d 0x7a 0x88 0x3b ]
#
# OUTPUT
# [0xb4 0x2a 0xf7 0x44 ]
# [0x93 0x42 0x5f 0x36 ]
# [0x8d 0x27 0xa2 0x2b ]
# [0xec 0xb8 0x84 0x52 ]
#
# SUB BYTES
# INPUT
# [0xb4 0x2a 0xf7 0x44 ]
# [0x93 0x42 0x5f 0x36 ]
# [0x8d 0x27 0xa2 0x2b ]
# [0xec 0xb8 0x84 0x52 ]
#
# OUTPUT
# [0x8d 0xe5 0x68 0x1b ]
# [0xdc 0x2c 0xcf 0x5 ]
# [0x5d 0xcc 0x3a 0xf1 ]
# [0xce 0x6c 0x5f 0x0 ]
#
# INPUT
# [0x8d 0xe5 0x68 0x1b ]
# [0xdc 0x2c 0xcf 0x5 ]
# [0x5d 0xcc 0x3a 0xf1 ]
# [0xce 0x6c 0x5f 0x0 ]
#
# OUTPUT
# [0x8d 0xe5 0x68 0x1b ]
# [0x2c 0xcf 0x5 0xdc ]
# [0x3a 0xf1 0x5d 0xcc ]
# [0x0 0xce 0x6c 0x5f ]
#
# INPUT
# [0x8d 0xe5 0x68 0x1b ]
# [0x2c 0xcf 0x5 0xdc ]
# [0x3a 0xf1 0x5d 0xcc ]
# [0x0 0xce 0x6c 0x5f ]
#
# OUTPUT
# [0x4f 0x9b 0xd5 0x9a ]
# [0xa4 0xa6 0x9a 0x8d ]
# [0xee 0xe9 0x63 0x38 ]
# [0xda 0xa8 0xa5 0x83 ]
#
# INPUT
# [0x4f 0x9b 0xd5 0x9a ]
# [0xa4 0xa6 0x9a 0x8d ]
# [0xee 0xe9 0x63 0x38 ]
# [0xda 0xa8 0xa5 0x83 ]
#
# CIPHER KEY
# [0xef 0x44 0xa5 0x41 ]
# [0xa8 0x52 0x5b 0x7f ]
# [0xb6 0x71 0x25 0x3b ]
# [0xdb 0xb 0xad 0x0 ]
#
# OUTPUT
# [0xa0 0xdf 0x70 0xdb ]
# [0xc 0xf4 0xc1 0xf2 ]
# [0x58 0x98 0x46 0x3 ]
# [0x1 0xa3 0x8 0x83 ]
#
# SUB BYTES
# INPUT
# [0xa0 0xdf 0x70 0xdb ]
# [0xc 0xf4 0xc1 0xf2 ]
# [0x58 0x98 0x46 0x3 ]
# [0x1 0xa3 0x8 0x83 ]
#
# OUTPUT
# [0xe0 0x9e 0x51 0xb9 ]
# [0xfe 0xbf 0x78 0x89 ]
# [0x6a 0x46 0x5a 0x7b ]
# [0x7c 0xa 0x30 0xec ]
#
# INPUT
# [0xe0 0x9e 0x51 0xb9 ]
# [0xfe 0xbf 0x78 0x89 ]
# [0x6a 0x46 0x5a 0x7b ]
# [0x7c 0xa 0x30 0xec ]
#
# OUTPUT
# [0xe0 0x9e 0x51 0xb9 ]
# [0xbf 0x78 0x89 0xfe ]
# [0x5a 0x7b 0x6a 0x46 ]
# [0xec 0x7c 0xa 0x30 ]
#
# INPUT
# [0xe0 0x9e 0x51 0xb9 ]
# [0xbf 0x78 0x89 0xfe ]
# [0x5a 0x7b 0x6a 0x46 ]
# [0xec 0x7c 0xa 0x30 ]
#
# OUTPUT
# [0xb7 0x87 0xc4 0x1d ]
# [0xa8 0x9f 0x94 0x42 ]
# [0x42 0xec 0x12 0x4 ]
# [0x6 0xa4 0x9b 0x8 ]
#
# INPUT
# [0xb7 0x87 0xc4 0x1d ]
# [0xa8 0x9f 0x94 0x42 ]
# [0x42 0xec 0x12 0x4 ]
# [0x6 0xa4 0x9b 0x8 ]
#
# CIPHER KEY
# [0xd4 0xd1 0xc6 0xf8 ]
# [0x7c 0x83 0x9d 0x87 ]
# [0xca 0xf2 0xb8 0xbc ]
# [0x11 0xf9 0x15 0xbc ]
#
# OUTPUT
# [0x63 0x56 0x2 0xe5 ]
# [0xd4 0x1c 0x9 0xc5 ]
# [0x88 0x1e 0xaa 0xb8 ]
# [0x17 0x5d 0x8e 0xb4 ]
#
# SUB BYTES
# INPUT
# [0x63 0x56 0x2 0xe5 ]
# [0xd4 0x1c 0x9 0xc5 ]
# [0x88 0x1e 0xaa 0xb8 ]
# [0x17 0x5d 0x8e 0xb4 ]
#
# OUTPUT
# [0xfb 0xb1 0x77 0xd9 ]
# [0x48 0x9c 0x1 0xa6 ]
# [0xc4 0x72 0xac 0x6c ]
# [0xf0 0x4c 0x19 0x8d ]
#
# INPUT
# [0xfb 0xb1 0x77 0xd9 ]
# [0x48 0x9c 0x1 0xa6 ]
# [0xc4 0x72 0xac 0x6c ]
# [0xf0 0x4c 0x19 0x8d ]
#
# OUTPUT
# [0xfb 0xb1 0x77 0xd9 ]
# [0x9c 0x1 0xa6 0x48 ]
# [0xac 0x6c 0xc4 0x72 ]
# [0x8d 0xf0 0x4c 0x19 ]
#
# INPUT
# [0xfb 0xb1 0x77 0xd9 ]
# [0x9c 0x1 0xa6 0x48 ]
# [0xac 0x6c 0xc4 0x72 ]
# [0x8d 0xf0 0x4c 0x19 ]
#
# OUTPUT
# [0x73 0xba 0xa8 0x27 ]
# [0xe6 0xf7 0x63 0x5e ]
# [0x97 0x3b 0x96 0x63 ]
# [0x1a 0xc6 0x5e 0x78 ]
#
# INPUT
# [0x73 0xba 0xa8 0x27 ]
# [0xe6 0xf7 0x63 0x5e ]
# [0x97 0x3b 0x96 0x63 ]
# [0x1a 0xc6 0x5e 0x78 ]
#
# CIPHER KEY
# [0x6d 0x88 0xa3 0x7a ]
# [0x11 0xb 0x3e 0xfd ]
# [0xdb 0xf9 0x86 0x41 ]
# [0xca 0x0 0x93 0xfd ]
#
# OUTPUT
# [0x1e 0x32 0xb 0x5d ]
# [0xf7 0xfc 0x5d 0xa3 ]
# [0x4c 0xc2 0x10 0x22 ]
# [0xd0 0xc6 0xcd 0x85 ]
#
# SUB BYTES
# INPUT
# [0x1e 0x32 0xb 0x5d ]
# [0xf7 0xfc 0x5d 0xa3 ]
# [0x4c 0xc2 0x10 0x22 ]
# [0xd0 0xc6 0xcd 0x85 ]
#
# OUTPUT
# [0x72 0x23 0x2b 0x4c ]
# [0x68 0xb0 0x4c 0xa ]
# [0x29 0x25 0xca 0x93 ]
# [0x70 0xb4 0xbd 0x97 ]
#
# INPUT
# [0x72 0x23 0x2b 0x4c ]
# [0x68 0xb0 0x4c 0xa ]
# [0x29 0x25 0xca 0x93 ]
# [0x70 0xb4 0xbd 0x97 ]
#
# OUTPUT
# [0x72 0x23 0x2b 0x4c ]
# [0xb0 0x4c 0xa 0x68 ]
# [0xca 0x93 0x29 0x25 ]
# [0x97 0x70 0xb4 0xbd ]
#
# INPUT
# [0x72 0x23 0x2b 0x4c ]
# [0xb0 0x4c 0xa 0x68 ]
# [0xca 0x93 0x29 0x25 ]
# [0x97 0x70 0xb4 0xbd ]
#
# OUTPUT
# [0x72 0xdb 0xef 0xd9 ]
# [0x71 0x65 0xc2 0x5a ]
# [0xd5 0xf0 0xb4 0x2d ]
# [0xb8 0x4e 0xb2 0xf8 ]
#
# INPUT
# [0x72 0xdb 0xef 0xd9 ]
# [0x71 0x65 0xc2 0x5a ]
# [0xd5 0xf0 0xb4 0x2d ]
# [0xb8 0x4e 0xb2 0xf8 ]
#
# CIPHER KEY
# [0x4e 0x54 0xf7 0xe ]
# [0x5f 0x5f 0xc9 0xf3 ]
# [0x84 0xa6 0x4f 0xb2 ]
# [0x4e 0xa6 0xdc 0x4f ]
#
# OUTPUT
# [0x3c 0x8f 0x18 0xd7 ]
# [0x2e 0x3a 0xb 0xa9 ]
# [0x51 0x56 0xfb 0x9f ]
# [0xf6 0xe8 0x6e 0xb7 ]
#
# SUB BYTES
# INPUT
# [0x3c 0x8f 0x18 0xd7 ]
# [0x2e 0x3a 0xb 0xa9 ]
# [0x51 0x56 0xfb 0x9f ]
# [0xf6 0xe8 0x6e 0xb7 ]
#
# OUTPUT
# [0xeb 0x73 0xad 0xe ]
# [0x31 0x80 0x2b 0xd3 ]
# [0xd1 0xb1 0xf 0xdb ]
# [0x42 0x9b 0x9f 0xa9 ]
#
# INPUT
# [0xeb 0x73 0xad 0xe ]
# [0x31 0x80 0x2b 0xd3 ]
# [0xd1 0xb1 0xf 0xdb ]
# [0x42 0x9b 0x9f 0xa9 ]
#
# OUTPUT
# [0xeb 0x73 0xad 0xe ]
# [0x80 0x2b 0xd3 0x31 ]
# [0xf 0xdb 0xd1 0xb1 ]
# [0xa9 0x42 0x9b 0x9f ]
#
# INPUT
# [0xeb 0x73 0xad 0xe ]
# [0x80 0x2b 0xd3 0x31 ]
# [0xf 0xdb 0xd1 0xb1 ]
# [0xa9 0x42 0x9b 0x9f ]
#
# OUTPUT
# [0xf0 0x48 0x95 0xe0 ]
# [0x2 0x11 0x33 0xe1 ]
# [0x65 0xe3 0x71 0xc3 ]
# [0x61 0x3b 0xfc 0xb7 ]
#
# INPUT
# [0xf0 0x48 0x95 0xe0 ]
# [0x2 0x11 0x33 0xe1 ]
# [0x65 0xe3 0x71 0xc3 ]
# [0x61 0x3b 0xfc 0xb7 ]
#
# CIPHER KEY
# [0xea 0xd2 0x73 0x21 ]
# [0xb5 0x8d 0xba 0xd2 ]
# [0x31 0x2b 0xf5 0x60 ]
# [0x7f 0x8d 0x29 0x2f ]
#
# OUTPUT
# [0x1a 0x9a 0xe6 0xc1 ]
# [0xb7 0x9c 0x89 0x33 ]
# [0x54 0xc8 0x84 0xa3 ]
# [0x1e 0xb6 0xd5 0x98 ]
#
# SUB BYTES
# INPUT
# [0x1a 0x9a 0xe6 0xc1 ]
# [0xb7 0x9c 0x89 0x33 ]
# [0x54 0xc8 0x84 0xa3 ]
# [0x1e 0xb6 0xd5 0x98 ]
#
# OUTPUT
# [0xa2 0xb8 0x8e 0x78 ]
# [0xa9 0xde 0xa7 0xc3 ]
# [0x20 0xe8 0x5f 0xa ]
# [0x72 0x4e 0x3 0x46 ]
#
# INPUT
# [0xa2 0xb8 0x8e 0x78 ]
# [0xa9 0xde 0xa7 0xc3 ]
# [0x20 0xe8 0x5f 0xa ]
# [0x72 0x4e 0x3 0x46 ]
#
# OUTPUT
# [0xa2 0xb8 0x8e 0x78 ]
# [0xde 0xa7 0xc3 0xa9 ]
# [0x5f 0xa 0x20 0xe8 ]
# [0x46 0x72 0x4e 0x3 ]
#
# INPUT
# [0xa2 0xb8 0x8e 0x78 ]
# [0xde 0xa7 0xc3 0xa9 ]
# [0x5f 0xa 0x20 0xe8 ]
# [0x46 0x72 0x4e 0x3 ]
#
# OUTPUT
# [0x3f 0xa2 0x8 0xf0 ]
# [0xe1 0x81 0x9d 0x9a ]
# [0x37 0x3d 0xdf 0xf6 ]
# [0xfb 0x11 0x1f 0xcf ]
#
# INPUT
# [0x3f 0xa2 0x8 0xf0 ]
# [0xe1 0x81 0x9d 0x9a ]
# [0x37 0x3d 0xdf 0xf6 ]
# [0xfb 0x11 0x1f 0xcf ]
#
# CIPHER KEY
# [0xac 0x77 0x66 0xf3 ]
# [0x19 0xfa 0xdc 0x21 ]
# [0x28 0xd1 0x29 0x41 ]
# [0x57 0x5c 0x0 0x6e ]
#
# OUTPUT
# [0x93 0xd5 0x6e 0x3 ]
# [0xf8 0x7b 0x41 0xbb ]
# [0x1f 0xec 0xf6 0xb7 ]
# [0xac 0x4d 0x1f 0xa1 ]
#
# SUB BYTES
# INPUT
# [0x93 0xd5 0x6e 0x3 ]
# [0xf8 0x7b 0x41 0xbb ]
# [0x1f 0xec 0xf6 0xb7 ]
# [0xac 0x4d 0x1f 0xa1 ]
#
# OUTPUT
# [0xdc 0x3 0x9f 0x7b ]
# [0x41 0x21 0x83 0xea ]
# [0xc0 0xce 0x42 0xa9 ]
# [0x91 0xe3 0xc0 0x32 ]
#
# INPUT
# [0xdc 0x3 0x9f 0x7b ]
# [0x41 0x21 0x83 0xea ]
# [0xc0 0xce 0x42 0xa9 ]
# [0x91 0xe3 0xc0 0x32 ]
#
# OUTPUT
# [0xdc 0x3 0x9f 0x7b ]
# [0x21 0x83 0xea 0x41 ]
# [0x42 0xa9 0xc0 0xce ]
# [0x32 0x91 0xe3 0xc0 ]
#
# INPUT
# [0xdc 0x3 0x9f 0x7b ]
# [0x21 0x83 0xea 0x41 ]
# [0x42 0xa9 0xc0 0xce ]
# [0x32 0x91 0xe3 0xc0 ]
#
# CIPHER KEY
# [0xd0 0x14 0xf9 0xa8 ]
# [0xc9 0xee 0x25 0x89 ]
# [0xe1 0x3f 0xc 0xc8 ]
# [0xb6 0x63 0xc 0xa6 ]
#
# OUTPUT
# [0xc 0x17 0x66 0xd3 ]
# [0xe8 0x6d 0xcf 0xc8 ]
# [0xa3 0x96 0xcc 0x6 ]
# [0x84 0xf2 0xef 0x66 ]
#
# 0xce8a384176d96f266cfccefd3c80666

# %%
from AES import *
from utils import *

# %%
# Testing for Key Expansion
key = convert_int_to_matrix(0x0f1571c947d9e8590cb7add6af7f6798)
printb(key, 'INPUT')
key_expansion(key)
# Out:
# INPUT
# [0xf 0x47 0xc 0xaf ]
# [0x15 0xd9 0xb7 0x7f ]
# [0x71 0xe8 0xad 0x67 ]
# [0xc9 0x59 0xd6 0x98 ]
#
# ['0xf', '0x47', '0xc', '0xaf']
# ['0x15', '0xd9', '0xb7', '0x7f']
# ['0x71', '0xe8', '0xad', '0x67']
# ['0xc9', '0x59', '0xd6', '0x98']
#
# ['0xdc', '0x9b', '0x97', '0x38']
# ['0x90', '0x49', '0xfe', '0x81']
# ['0x37', '0xdf', '0x72', '0x15']
# ['0xb0', '0xe9', '0x3f', '0xa7']
#
# ['0xd2', '0x49', '0xde', '0xe6']
# ['0xc9', '0x80', '0x7e', '0xff']
# ['0x6b', '0xb4', '0xc6', '0xd3']
# ['0xb7', '0x5e', '0x61', '0xc6']
#
# ['0xc0', '0x89', '0x57', '0xb1']
# ['0xaf', '0x2f', '0x51', '0xae']
# ['0xdf', '0x6b', '0xad', '0x7e']
# ['0x39', '0x67', '0x6', '0xc0']
#
# ['0x2c', '0xa5', '0xf2', '0x43']
# ['0x5c', '0x73', '0x22', '0x8c']
# ['0x65', '0xe', '0xa3', '0xdd']
# ['0xf1', '0x96', '0x90', '0x50']
#
# ['0x58', '0xfd', '0xf', '0x4c']
# ['0x9d', '0xee', '0xcc', '0x40']
# ['0x36', '0x38', '0x9b', '0x46']
# ['0xeb', '0x7d', '0xed', '0xbd']
#
# ['0x71', '0x8c', '0x83', '0xcf']
# ...

# %%
from AES import *
from utils import *

# %%
input = 0x2b7e151628aed2a6abf7158809cf4f3c
input = convert_int_to_matrix(input)

# %%
# Out:
# ['0x2b', '0x7e', '0x15', '0x16']
# ['0x28', '0xae', '0xd2', '0xa6']
# ['0xab', '0xf7', '0x15', '0x88']
# ['0x9', '0xcf', '0x4f', '0x3c']
# ['0xa0', '0xfa', '0xfe', '0x17']
# ['0x88', '0x54', '0x2c', '0xb1']
# ['0x23', '0xa3', '0x39', '0x39']
# ['0x2a', '0x6c', '0x76', '0x5']
# ['0xf2', '0xc2', '0x95', '0xf2']
# ['0x7a', '0x96', '0xb9', '0x43']
# ['0x59', '0x35', '0x80', '0x7a']
# ['0x73', '0x59', '0xf6', '0x7f']
# ['0x3d', '0x80', '0x47', '0x7d']
# ['0x47', '0x16', '0xfe', '0x3e']
# ['0x1e', '0x23', '0x7e', '0x44']
# ['0x6d', '0x7a', '0x88', '0x3b']
# ['0xef', '0x44', '0xa5', '0x41']
# ['0xa8', '0x52', '0x5b', '0x7f']
# ['0xb6', '0x71', '0x25', '0x3b']
# ['0xdb', '0xb', '0xad', '0x0']
# ['0xd4', '0xd1', '0xc6', '0xf8']
# ['0x7c', '0x83', '0x9d', '0x87']
# ['0xca', '0xf2', '0xb8', '0xbc']
# ['0x11', '0xf9', '0x15', '0xbc']
# ['0x6d', '0x88', '0xa3', '0x7a']
# ['0x11', '0xb', '0x3e', '0xfd']
# ['0xdb', '0xf9', '0x86', '0x41']
# ['0xca', '0x0', '0x93', '0xfd']
# ...

# %%
from AES import *
from utils import *

# %%
plaintext_matrix = convert_int_to_matrix(0x00102030011121310212223203132333)
key_matrix = convert_int_to_matrix(key)
printb(plaintext_matrix, '')
print(hex(convert_matrix_to_int(plaintext_matrix)))
# Out:
# [0x0 0x1 0x2 0x3 ]
# [0x10 0x11 0x12 0x13 ]
# [0x20 0x21 0x22 0x23 ]
# [0x30 0x31 0x32 0x33 ]

# %%
printb(plaintext_matrix, '')
printb(shift_rows(plaintext_matrix), '')
print(hex(convert_matrix_to_int(shift_rows(plaintext_matrix))))
# Out:
# [0x0 0x1 0x2 0x3 ]
# [0x10 0x11 0x12 0x13 ]
# [0x20 0x21 0x22 0x23 ]
# [0x30 0x31 0x32 0x33 ]
#
# [0x0 0x1 0x2 0x3 ]
# [0x11 0x12 0x13 0x10 ]
# [0x22 0x23 0x20 0x21 ]
# [0x33 0x30 0x31 0x32 ]
#
# 0x112233011223300213203103102132

# %%
print(hex(aes_encrypt(plaintext, key)))
# Out:
# 0xc2295810b26111eaa42e243c09412506

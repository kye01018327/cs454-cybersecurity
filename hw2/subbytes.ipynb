# %%
from AES import *
from test_data import plaintext, key

# %%
temp = plaintext

# %%
sub_bytes()
# Out:
# '0b1001000110100010101100111100010011010101111001101111011110000000100100011010001010110011110001001101010111100110111101111'
